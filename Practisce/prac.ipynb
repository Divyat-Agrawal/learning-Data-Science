# %% [markdown]
# ## ASSIGNMENT - 3

# %% [markdown]
# ## Q1

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,2*np.pi,0.1)
y= np.sin(x)
# z= np.cos(x)
plt.plot(x,y,color = "blue" , marker = "o", linestyle = "dotted")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend(['sinx'])
plt.show()

# %%
import matplotlib.pyplot as plt
y = [1, 25, 74, 65, 71, 89]
x = [15, 40, 67, 41, 88, 94]
plt.xlabel("x-axix")
plt.ylabel("y-axix")
plt.title("Marks")
plt.plot(x,y,color ="green" , linestyle = "dotted")
plt.show()

# %% [markdown]
# ## Q2

# %%
import matplotlib.pyplot as plt
langs = ['Spanish', 'French', 'English', 'Hindi', 'Korean']
students = [40,64,75,88,95]

plt.bar(langs,students)
plt.show()

# %% [markdown]
# ## Q3

# %%
# HISTOGRAM
data1 = np.random.randn(1000)
plt.hist(data1, bins=30, density=True, alpha=0.5,histtype='stepfilled', color='steelblue')
plt.show();

# %%
# DENSITY PLOT

import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
data = np.random.randn(1000)  # Generate 1000 random data points from a standard normal distribution

# Create a histogram
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)  # Create a subplot for the histogram

# You can adjust the number of bins, color, and transparency
plt.hist(data, bins=20, color='skyblue', alpha=0.7, edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram")

# Create a density plot
plt.subplot(1, 2, 2)  # Create a subplot for the density plot

# You can adjust the bandwidth and color
plt.hist(data, bins=20, density=True, color='salmon', alpha=0.7, edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Density Plot")

plt.tight_layout()  # Adjust spacing for subplots
plt.show()

# %% [markdown]
# ## Q4

# %%
np.random.seed(196801)
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2

plt.scatter(x, y, s=area, c=colors, alpha=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
x = np.random.rand(50)  # 50 random x-coordinates
y = np.random.rand(50)  # 50 random y-coordinates
colors = np.random.rand(50)  # Random color values
sizes = 100 * np.random.rand(50)  # Random sizes for points

# Create a scatter plot
plt.scatter(x, y, c=colors, s=sizes, cmap='viridis', alpha=0.7, edgecolors='k')

# Add labels and a colorbar
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter Plot with Different Parameters")

# Add a color bar to show the relationship between color and data values
plt.colorbar()

# Display the plot
plt.show()
